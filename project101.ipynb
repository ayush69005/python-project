# %% [markdown]
# # Apple Phone Sales Analysis

# %%
# importing libraries:
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Reading the csv file:
dataset= pd.read_csv("apple_products (1).csv")
dataset
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# cleaning of data:
# 1. missing values
Missing= dataset.isnull().sum()
Missing
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64

# %%
# 2. removing duplicate values:
Duplicate= dataset.duplicated()
Duplicate
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
# Finding statistical data:
stat_data= dataset.describe()
stat_data
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# ...

# %%
# Sorting of data:
Highest_rated= dataset.sort_values(by='Star Rating',ascending=False).reset_index()
print(Highest_rated['Product Name'])
# Out:
# 0                APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 1      APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 2          APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 3     APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 4               APPLE iPhone 11 Pro Max (Gold, 256 GB)
#                             ...
# 57                      APPLE iPhone SE (White, 64 GB)
# 58                     APPLE iPhone SE (Black, 128 GB)
# 59                      APPLE iPhone SE (Black, 64 GB)
# 60                     APPLE iPhone SE (White, 128 GB)
# 61                       APPLE iPhone SE (Red, 128 GB)
# Name: Product Name, Length: 62, dtype: object

# %%
# Finding to top N apple phone sold:
# let say N=10 
Highest_rated= Highest_rated.head(10)
print(Highest_rated['Product Name'])
# Out:
# 0                APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 1      APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 2          APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 3     APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 4               APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 5                    APPLE iPhone 8 Plus (Gold, 64 GB)
# 6    Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 7    Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 8    Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 9             APPLE iPhone 8 Plus (Space Grey, 256 GB)
# Name: Product Name, dtype: object

# %%
# visulization of data : number of rating by top 10 product .

sns.barplot(data=Highest_rated, x='Product Name', y='Number Of Ratings')
plt.title('Rating VS Product')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# plot a scatter graph to represent sales price by number of rating 

sns.regplot(data=dataset, 
                     x= 'Number Of Ratings', 
                       y=  'Sale Price', scatter=True, 
                         line_kws={"color": "green"})
plt.title('Sales Price by Number of rating')
plt.show()

# %%
# plotting graph to represent discount percentage by number of rating:
Graph3= sns.regplot(data=dataset,
                     x= 'Number Of Ratings',
                       y=  'Discount Percentage',
                         scatter=True,
                           line_kws={"color": "green"})
plt.title('Discount percentage by Rating')
plt.show()
